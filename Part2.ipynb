# %% [markdown]
# # Model Fitting

# %% [markdown]
# Now that we have processed the data, we can use the cleaned data to model and predict the chances of someone being approved for a loan.

# %% [markdown]
# Based on the EDA, we find that the factor that is most strongly correlated to the loan status would be the credit score of an individual. We also find that credit cards have the highest loan status approval rate among loan types. Among loan use cases, we observe that education and personal use cases generally have higher loan approval ratings, while debt consolidation and business reasons tend to decrease loan approval ratings.

# %% [markdown]
# Since the outcome we are trying to model is binary, $y_i \sim \operatorname{Bern}(p_i)$, then a model that is well-suited to fit the data would be the logistic regression, as it is catered to fit data whose output is binary in nature. The output of a logistic regression is a probability value $\hat \pi_i$, which is not binary in nature, so to convert it to a binary value, we will implement a cutoff threshold, $k$, we then define $\hat y_i = I\{\hat \pi_i \ge k\}$, where $I\{x\}$ is the indicator function. To prevent overfitting, we want to use a train/test split and we will quantify the performance of our model by using the classification rate on the test set, where we define the classification rate as $\frac{I\{y_i = \hat y_i\}}{n}$. Since the cutoff value is arbitrarily defined, we can implement a grid search approach to find an optimal cutoff threshold that will maximize our classification rate.

# %% [markdown]
# # Data Processing and Exploration

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from loan_tools.fittools import get_classification_rate, best_alpha

# %%
df = pd.read_csv("data/cleaned_data.csv")
df.head(5)
# Out:
#    age occupation_status  years_employed  annual_income  credit_score  \
# 0   40          Employed            17.2          25579           692
# 1   33          Employed             7.3          43087           627
# 2   42           Student             1.1          20840           689
# 3   53           Student             0.5          29147           692
# 4   32          Employed            12.5          63657           630
#
#    credit_history_years  savings_assets  current_debt  defaults_on_file  \
# 0                   5.3             895         10820                 0
# 1                   3.5             169         16550                 0
# 2                   8.4              17          7852                 0
# 3                   9.8            1480         11603                 0
# 4                   7.2             209         12424                 0
#
#    delinquencies_last_2yrs  derogatory_marks   product_type  \
# 0                        0                 0    Credit Card
# 1                        1                 0  Personal Loan
# 2                        0                 0    Credit Card
# 3                        1                 0    Credit Card
# 4                        0                 0  Personal Loan
#
#           loan_intent  loan_amount  interest_rate  debt_to_income_ratio  \
# 0            Business          600          17.02                 0.423
# 1    Home Improvement        53300          14.10                 0.384
# 2  Debt Consolidation         2100          18.33                 0.377
# 3            Business         2900          18.74                 0.398
# 4           Education        99600          13.92                 0.195
#
#    loan_to_income_ratio  payment_to_income_ratio  loan_status
# 0                 0.023                    0.008            1
# 1                 1.237                    0.412            0
# 2                 0.101                    0.034            1
# 3                 0.099                    0.033            1
# 4                 1.565                    0.522            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      50000 non-null  int64
#  1   occupation_status        50000 non-null  object
#  2   years_employed           50000 non-null  float64
#  3   annual_income            50000 non-null  int64
#  4   credit_score             50000 non-null  int64
#  5   credit_history_years     50000 non-null  float64
#  6   savings_assets           50000 non-null  int64
#  7   current_debt             50000 non-null  int64
#  8   defaults_on_file         50000 non-null  int64
#  9   delinquencies_last_2yrs  50000 non-null  int64
#  10  derogatory_marks         50000 non-null  int64
#  11  product_type             50000 non-null  object
#  12  loan_intent              50000 non-null  object
#  13  loan_amount              50000 non-null  int64
#  14  interest_rate            50000 non-null  float64
#  15  debt_to_income_ratio     50000 non-null  float64
#  16  loan_to_income_ratio     50000 non-null  float64
#  17  payment_to_income_ratio  50000 non-null  float64
#  18  loan_status              50000 non-null  int64
# dtypes: float64(6), int64(10), object(3)
# memory usage: 7.2+ MB

# %% [markdown]
# ## One Hot Encoding and Train/Test Splitting

# %%
df = pd.get_dummies(df, columns = ['loan_intent', 'product_type', 'occupation_status'], drop_first = True)

# %%
df.columns
# Out:
# Index(['age', 'years_employed', 'annual_income', 'credit_score',
#        'credit_history_years', 'savings_assets', 'current_debt',
#        'defaults_on_file', 'delinquencies_last_2yrs', 'derogatory_marks',
#        'loan_amount', 'interest_rate', 'debt_to_income_ratio',
#        'loan_to_income_ratio', 'payment_to_income_ratio', 'loan_status',
#        'loan_intent_Debt Consolidation', 'loan_intent_Education',
#        'loan_intent_Home Improvement', 'loan_intent_Medical',
#        'loan_intent_Personal', 'product_type_Line of Credit',
#        'product_type_Personal Loan', 'occupation_status_Self-Employed',
#        'occupation_status_Student'],
#       dtype='object')

# %%
train, test = df[:-10000], df[-10000:]

# %% [markdown]
# ## Model Fitting

# %% [markdown]
# Using the information from the preface, we can naively fit a model using the loan intent, product type, and credit score to see how our model performs.

# %%
y = train['loan_status']
X_cols_naive = ['loan_intent_Debt Consolidation', 'loan_intent_Education',
       'loan_intent_Home Improvement', 'loan_intent_Medical',
       'loan_intent_Personal', 'product_type_Line of Credit',
       'product_type_Personal Loan', 'credit_score']
X_naive = sm.add_constant(train[X_cols_naive].astype(int))

model_naive = sm.Logit(y, X_naive).fit()
print("Using our naive model, we achieve a classification performance of " + str(get_classification_rate(md = model_naive, X = X_cols_naive, df = test)[0]) + "%")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.510260
#          Iterations 6

# %% [markdown]
# We find that our naive approach produces a model that is correct about 76% of the time, however, we can definitely make a model that performs better.

# %% [markdown]
# ## Regularized Model Fitting

# %% [markdown]
# Regularization is a common technique used to impose a penalty, $\alpha$, on our regressor coefficients, $\beta$, this penalty will help find regressors that are stronger for prediction. As $\alpha \rightarrow \infty$, our $\beta \rightarrow 0$, helping reduce our model complexity and finding the strongest regressors. One issue that would occur is how do we find the optimal $\alpha$ such that we get the highest classification rate? To solve this, we can simply do a grid search to find the model that maximizes our classification rate. Since statsmodels only supports Tikhonov regularization, we will only test Tikhonov regularization.

# %%
best_model_l1, best_classification_l1, best_alpha_l1 = best_alpha(np.logspace(0, 5, num=6), train, test, lp = 'l1')
print("At an regularization penalty of " + str(best_alpha_l1) + ", we achieve the best classification performance with a performance of " + str(best_classification_l1[0]) + "%")
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2924303854344738
#             Iterations: 439
#             Function evaluations: 478
#             Gradient evaluations: 439
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.3007469993924006
#             Iterations: 291
#             Function evaluations: 330
#             Gradient evaluations: 291
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.35915056797900646
#             Iterations: 133
#             Function evaluations: 173
#             Gradient evaluations: 133
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5105345618492686
#             Iterations: 38
#             Function evaluations: 77
#             Gradient evaluations: 38
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5841872986432503
#             Iterations: 16
#             Function evaluations: 55
#             Gradient evaluations: 16
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6146973298560827
#             Iterations: 11
#             Function evaluations: 47
#             Gradient evaluations: 11
# At an regularization penalty of 1.0, we achieve the best classification performance with a performance of 86.79%

# %% [markdown]
# By implementing Tikhonov Regularization with a penalty of $\alpha = 1$, we managed to improve our classification performance from 76% to 86%, which is a significant improvement. We can then do a finer grid search to further optimize our model.

# %%
best_model_l1_fine, best_classification_l1_fine, best_alpha_l1_fine = best_alpha(np.linspace(0.01, 1, num = 100), train, test, lp = 'l1')
print("At an regularization penalty of " + str(best_alpha_l1_fine) + ", we achieve the best classification performance with a performance of " + str(best_classification_l1_fine[0]) + "%")
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2913196776442528
#             Iterations: 150
#             Function evaluations: 189
#             Gradient evaluations: 150
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29134805983118695
#             Iterations: 149
#             Function evaluations: 188
#             Gradient evaluations: 149
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29137524300019674
#             Iterations: 144
#             Function evaluations: 183
#             Gradient evaluations: 144
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2913514780542294
#             Iterations: 324
#             Function evaluations: 363
#             Gradient evaluations: 324
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29135592261440524
#             Iterations: 424
#             Function evaluations: 463
#             Gradient evaluations: 424
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29136777387887347
#             Iterations: 448
#             Function evaluations: 487
#             Gradient evaluations: 448
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29137868958206126
#             Iterations: 471
#             Function evaluations: 510
#             Gradient evaluations: 471
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29139193885132986
#             Iterations: 456
#             Function evaluations: 496
#             Gradient evaluations: 456
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2913994609836248
#             Iterations: 509
#             Function evaluations: 548
#             Gradient evaluations: 509
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2914112953997491
#             Iterations: 524
#             Function evaluations: 563
#             Gradient evaluations: 524
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2914266782108085
#             Iterations: 479
#             Function evaluations: 518
#             Gradient evaluations: 479
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29143503229937484
#             Iterations: 528
#             Function evaluations: 567
#             Gradient evaluations: 528
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29144889713275407
#             Iterations: 501
#             Function evaluations: 540
#             Gradient evaluations: 501
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2914589478107376
#             Iterations: 535
#             Function evaluations: 574
#             Gradient evaluations: 535
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2914705010559435
#             Iterations: 526
#             Function evaluations: 565
#             Gradient evaluations: 526
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29148316413159675
#             Iterations: 496
#             Function evaluations: 536
#             Gradient evaluations: 496
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2914939058240738
#             Iterations: 509
#             Function evaluations: 548
#             Gradient evaluations: 509
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2915054878303376
#             Iterations: 500
#             Function evaluations: 539
#             Gradient evaluations: 500
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29151783228777667
#             Iterations: 519
#             Function evaluations: 558
#             Gradient evaluations: 519
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29152993840456115
#             Iterations: 502
#             Function evaluations: 542
#             Gradient evaluations: 502
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29154117569433563
#             Iterations: 501
#             Function evaluations: 540
#             Gradient evaluations: 501
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2915527455856784
#             Iterations: 494
#             Function evaluations: 533
#             Gradient evaluations: 494
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29156465298517276
#             Iterations: 498
#             Function evaluations: 538
#             Gradient evaluations: 498
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29157612471969946
#             Iterations: 497
#             Function evaluations: 537
#             Gradient evaluations: 497
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2915897011679431
#             Iterations: 506
#             Function evaluations: 546
#             Gradient evaluations: 506
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29159997728955783
#             Iterations: 480
#             Function evaluations: 519
#             Gradient evaluations: 480
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29161122388027755
#             Iterations: 491
#             Function evaluations: 530
#             Gradient evaluations: 491
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29162273234417
#             Iterations: 496
#             Function evaluations: 536
#             Gradient evaluations: 496
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29163612323061894
#             Iterations: 466
#             Function evaluations: 505
#             Gradient evaluations: 466
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2916471565881749
#             Iterations: 479
#             Function evaluations: 519
#             Gradient evaluations: 479
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2916581216774527
#             Iterations: 469
#             Function evaluations: 508
#             Gradient evaluations: 469
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29166947619315464
#             Iterations: 474
#             Function evaluations: 513
#             Gradient evaluations: 474
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2916803543618541
#             Iterations: 467
#             Function evaluations: 507
#             Gradient evaluations: 467
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2916925480788399
#             Iterations: 462
#             Function evaluations: 501
#             Gradient evaluations: 462
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2917037307767179
#             Iterations: 483
#             Function evaluations: 522
#             Gradient evaluations: 483
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29171544331697336
#             Iterations: 464
#             Function evaluations: 503
#             Gradient evaluations: 464
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29172683744086414
#             Iterations: 471
#             Function evaluations: 510
#             Gradient evaluations: 471
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2917381744634019
#             Iterations: 470
#             Function evaluations: 509
#             Gradient evaluations: 470
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2917498126234349
#             Iterations: 475
#             Function evaluations: 515
#             Gradient evaluations: 475
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2917605049369835
#             Iterations: 486
#             Function evaluations: 525
#             Gradient evaluations: 486
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29177298991204065
#             Iterations: 472
#             Function evaluations: 511
#             Gradient evaluations: 472
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2917842203623261
#             Iterations: 467
#             Function evaluations: 506
#             Gradient evaluations: 467
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29179575432546384
#             Iterations: 468
#             Function evaluations: 507
#             Gradient evaluations: 468
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29180651826930115
#             Iterations: 451
#             Function evaluations: 490
#             Gradient evaluations: 451
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29181845854291033
#             Iterations: 455
#             Function evaluations: 494
#             Gradient evaluations: 455
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2918299356041828
#             Iterations: 461
#             Function evaluations: 501
#             Gradient evaluations: 461
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2918412908730346
#             Iterations: 458
#             Function evaluations: 497
#             Gradient evaluations: 458
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29185239045454153
#             Iterations: 474
#             Function evaluations: 513
#             Gradient evaluations: 474
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29186385046344043
#             Iterations: 469
#             Function evaluations: 508
#             Gradient evaluations: 469
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2918753119195301
#             Iterations: 467
#             Function evaluations: 506
#             Gradient evaluations: 467
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2918863913231129
#             Iterations: 457
#             Function evaluations: 496
#             Gradient evaluations: 457
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2918973763218109
#             Iterations: 465
#             Function evaluations: 504
#             Gradient evaluations: 465
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2919089194800071
#             Iterations: 462
#             Function evaluations: 501
#             Gradient evaluations: 462
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29192008596749797
#             Iterations: 463
#             Function evaluations: 502
#             Gradient evaluations: 463
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2919316858878614
#             Iterations: 454
#             Function evaluations: 494
#             Gradient evaluations: 454
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29194297853179674
#             Iterations: 447
#             Function evaluations: 486
#             Gradient evaluations: 447
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2919539503529658
#             Iterations: 459
#             Function evaluations: 498
#             Gradient evaluations: 459
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29196542145010856
#             Iterations: 441
#             Function evaluations: 480
#             Gradient evaluations: 441
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2919769267778657
#             Iterations: 447
#             Function evaluations: 486
#             Gradient evaluations: 447
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29198812515229794
#             Iterations: 451
#             Function evaluations: 491
#             Gradient evaluations: 451
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2919996815539728
#             Iterations: 439
#             Function evaluations: 478
#             Gradient evaluations: 439
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2920101704766686
#             Iterations: 469
#             Function evaluations: 508
#             Gradient evaluations: 469
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2920216399398527
#             Iterations: 466
#             Function evaluations: 505
#             Gradient evaluations: 466
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29203260212179855
#             Iterations: 462
#             Function evaluations: 501
#             Gradient evaluations: 462
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2920438036280049
#             Iterations: 457
#             Function evaluations: 496
#             Gradient evaluations: 457
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2920551698559306
#             Iterations: 458
#             Function evaluations: 497
#             Gradient evaluations: 458
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2920660765571332
#             Iterations: 453
#             Function evaluations: 492
#             Gradient evaluations: 453
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29207748539476647
#             Iterations: 451
#             Function evaluations: 491
#             Gradient evaluations: 451
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29208874346532254
#             Iterations: 442
#             Function evaluations: 481
#             Gradient evaluations: 442
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29209976218083705
#             Iterations: 439
#             Function evaluations: 479
#             Gradient evaluations: 439
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29211047456981043
#             Iterations: 441
#             Function evaluations: 480
#             Gradient evaluations: 441
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29212186515896876
#             Iterations: 445
#             Function evaluations: 484
#             Gradient evaluations: 445
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2921329259300201
#             Iterations: 446
#             Function evaluations: 485
#             Gradient evaluations: 446
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29214526506581456
#             Iterations: 453
#             Function evaluations: 493
#             Gradient evaluations: 453
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29215509940538315
#             Iterations: 445
#             Function evaluations: 484
#             Gradient evaluations: 445
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2921662483810711
#             Iterations: 447
#             Function evaluations: 486
#             Gradient evaluations: 447
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2921772141671043
#             Iterations: 465
#             Function evaluations: 504
#             Gradient evaluations: 465
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29218829630325477
#             Iterations: 445
#             Function evaluations: 484
#             Gradient evaluations: 445
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2921994011052984
#             Iterations: 458
#             Function evaluations: 497
#             Gradient evaluations: 458
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2922104559730318
#             Iterations: 445
#             Function evaluations: 484
#             Gradient evaluations: 445
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2922215726008978
#             Iterations: 459
#             Function evaluations: 498
#             Gradient evaluations: 459
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29223269452068645
#             Iterations: 447
#             Function evaluations: 487
#             Gradient evaluations: 447
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2922437155078978
#             Iterations: 448
#             Function evaluations: 487
#             Gradient evaluations: 448
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29225476614629786
#             Iterations: 455
#             Function evaluations: 494
#             Gradient evaluations: 455
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2922657396639945
#             Iterations: 462
#             Function evaluations: 501
#             Gradient evaluations: 462
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29227683265711385
#             Iterations: 452
#             Function evaluations: 491
#             Gradient evaluations: 452
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2922879177378789
#             Iterations: 451
#             Function evaluations: 490
#             Gradient evaluations: 451
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29229894523660566
#             Iterations: 437
#             Function evaluations: 476
#             Gradient evaluations: 437
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2923099101004219
#             Iterations: 443
#             Function evaluations: 482
#             Gradient evaluations: 443
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29232087660017025
#             Iterations: 463
#             Function evaluations: 502
#             Gradient evaluations: 463
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29233181962466026
#             Iterations: 442
#             Function evaluations: 481
#             Gradient evaluations: 442
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2923427715849704
#             Iterations: 440
#             Function evaluations: 479
#             Gradient evaluations: 440
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29235383932525555
#             Iterations: 431
#             Function evaluations: 470
#             Gradient evaluations: 431
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2923647638250685
#             Iterations: 441
#             Function evaluations: 480
#             Gradient evaluations: 441
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2923756839338353
#             Iterations: 435
#             Function evaluations: 474
#             Gradient evaluations: 435
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2923866684402416
#             Iterations: 453
#             Function evaluations: 492
#             Gradient evaluations: 453
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29239764842395666
#             Iterations: 447
#             Function evaluations: 486
#             Gradient evaluations: 447
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.29240858710465045
#             Iterations: 421
#             Function evaluations: 461
#             Gradient evaluations: 421
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2924195539805207
#             Iterations: 427
#             Function evaluations: 466
#             Gradient evaluations: 427
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2924303854344738
#             Iterations: 439
#             Function evaluations: 478
#             Gradient evaluations: 439
# At an regularization penalty of 0.99, we achieve the best classification performance with a performance of 86.8%

# %% [markdown]
# Based on our finer grid search, we find that the optimal $\alpha=0.99$, this further improves our classification performance from 86.79% to 86.8%, which is a marginal improvement from before.
